# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_excel("new_table.xlsx", header = 0, sheet_name="new_table")
raw.head()
# Out:
#    식당(ID)    식당명  지점명  지역명 어워드정보설명   (RTI)지수 온라인화진행여부  수용태세지수   인기도  \
# 0  108660    베누스  NaN  양천구     NaN  0.910544        N   0.202   NaN
# 1  109087  돌솥바베큐  NaN  양천구     NaN  0.910544        N   0.202   NaN
# 2  109732    화이팅  NaN  양천구     NaN  3.815154        N   0.217  0.01
# 3  109976  선가네분식  NaN  양천구     NaN  0.910544        N   0.202   NaN
# 4  110607  칼포니호프  NaN  양천구     NaN  0.910544        N   0.202   NaN
#
#    트립어드바이저평점  씨트립평점  네이버평점
# 0        NaN    NaN    5.0
# 1        NaN    NaN    5.0
# 2        NaN    NaN    5.0
# 3        NaN    NaN    5.0
# 4        NaN    NaN    5.0

# %%
my_area = raw[raw['지역명'].isin(['종로구','양천구','용산구','서대문구','성북구'])][['식당(ID)','식당명', '지점명','지역명','네이버평점']]

my_area.head(10)
# Out:
#    식당(ID)    식당명  지점명  지역명  네이버평점
# 0  108660    베누스  NaN  양천구    5.0
# 1  109087  돌솥바베큐  NaN  양천구    5.0
# 2  109732    화이팅  NaN  양천구    5.0
# 3  109976  선가네분식  NaN  양천구    5.0
# 4  110607  칼포니호프  NaN  양천구    5.0
# 5  111053   광장호프  NaN  양천구    5.0
# 6  111235  섬마을포차  NaN  양천구    5.0
# 7  111719    금순네  NaN  양천구    5.0
# 8  111958   연가포차  NaN  양천구    5.0
# 9  112054    동호정  NaN  양천구    5.0

# %%
import numpy as np

# NaN 값을 처리하기 위해 numpy를 import합니다.

my_area['식당명+지점명'] = np.where(
    my_area['지점명'].notna(),
    my_area['식당명'].astype(str) + " " + my_area['지점명'].astype(str),
    my_area['지역명'] + " " + my_area['식당명'].astype(str)
)

my_area.head(10)
# Out:
#    식당(ID)    식당명  지점명  지역명  네이버평점    식당명+지점명
# 0  108660    베누스  NaN  양천구    5.0    양천구 베누스
# 1  109087  돌솥바베큐  NaN  양천구    5.0  양천구 돌솥바베큐
# 2  109732    화이팅  NaN  양천구    5.0    양천구 화이팅
# 3  109976  선가네분식  NaN  양천구    5.0  양천구 선가네분식
# 4  110607  칼포니호프  NaN  양천구    5.0  양천구 칼포니호프
# 5  111053   광장호프  NaN  양천구    5.0   양천구 광장호프
# 6  111235  섬마을포차  NaN  양천구    5.0  양천구 섬마을포차
# 7  111719    금순네  NaN  양천구    5.0    양천구 금순네
# 8  111958   연가포차  NaN  양천구    5.0   양천구 연가포차
# 9  112054    동호정  NaN  양천구    5.0    양천구 동호정

# %%
name_list = my_area['식당명+지점명'].tolist()
name_list = name_list
name_list[:10]
# Out:
# ['양천구 베누스',
#  '양천구 돌솥바베큐',
#  '양천구 화이팅',
#  '양천구 선가네분식',
#  '양천구 칼포니호프',
#  '양천구 광장호프',
#  '양천구 섬마을포차',
#  '양천구 금순네',
#  '양천구 연가포차',
#  '양천구 동호정']

# %%
import requests

res_info_list = []
no_place = []

for searching in name_list:
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    headers = {
        "Authorization": "KakaoAK b9f489946ca62947a1d9b5320150e4a7"
    }
    places = requests.get(url, headers=headers).json()['documents']
    
    if len(places) <= 0:
        places = {'address_name': np.nan,
                 'category_group_code': np.nan,
                 'category_group_name': np.nan,
                 'category_name': np.nan,
                 'distance': np.nan,
                 'id': np.nan,
                 'phone': np.nan,
                 'place_name': np.nan,
                 'place_url': np.nan,
                 'road_address_name': np.nan,
                 'x': np.nan,
                 'y': np.nan}
        res_info_list.append(places)
        
    else:
        res_info_list.append(places[0])

# %%
len(res_info_list)
# Out:
# 5000

# %%
res_info_df = pd.DataFrame(res_info_list)
res_info_df['평점'] = raw['네이버평점']
res_info_df.loc[res_info_df['address_name'].isna(), '평점'] = np.nan

# %%
res_info_df[:10]
# Out:
#         address_name category_group_code category_group_name  \
# 0   서울 구로구 구로동 476-6
# 1  서울 양천구 신월동 110-29                 FD6                 음식점
# 2    서울 양천구 목동 601-2                 FD6                 음식점
# 3    서울 양천구 신정동 1294                 FD6                 음식점
# 4    서울 양천구 신월동 62-3                 FD6                 음식점
# 5    서울 양천구 신월동 85-6                 FD6                 음식점
# 6  서울 금천구 독산동 974-25                 FD6                 음식점
# 7                NaN                 NaN                 NaN
# 8                NaN                 NaN                 NaN
# 9     서울 강서구 마곡동 757                 FD6                 음식점
#
#         category_name distance          id         phone place_name  \
# 0    가정,생활 > 미용 > 미용실            678641450   02-866-3511     베누스헤어샵
# 1  음식점 > 술집 > 호프,요리주점             16847780  02-2695-6643      돌솥바베큐
# 2            음식점 > 한식             16052371                      화이팅
# 3            음식점 > 분식             20540817  02-2697-8998      선가네분식
# 4  음식점 > 술집 > 호프,요리주점            365036181                    칼포니호프
# 5  음식점 > 술집 > 호프,요리주점             16933981  02-2601-1360       호프광장
# 6    음식점 > 한식 > 해물,생선            845885022   02-839-7959        섬마을
# 7                 NaN      NaN         NaN           NaN        NaN
# 8                 NaN      NaN         NaN           NaN        NaN
# 9            음식점 > 한식           1766770993  02-2604-5292        동호정
#
#                                place_url    road_address_name  \
# 0   http://place.map.kakao.com/678641450  서울 구로구 구로동로47길 11-1
# 1    http://place.map.kakao.com/16847780   서울 양천구 곰달래로5길 22-1
# 2    http://place.map.kakao.com/16052371  서울 양천구 목동중앙북로 33-20
# 3    http://place.map.kakao.com/20540817      서울 양천구 신정로14길 1
# 4   http://place.map.kakao.com/365036181       서울 양천구 월정로 229
# 5    http://place.map.kakao.com/16933981       서울 양천구 월정로 215
# 6   http://place.map.kakao.com/845885022       서울 금천구 독산로 324
# 7                                    NaN                  NaN
# 8                                    NaN                  NaN
# 9  http://place.map.kakao.com/1766770993   서울 강서구 마곡중앙로 161-8
#
#                     x                   y   평점
# 0    126.881830215046    37.4979737893589  5.0
# 1    126.833882712082    37.5316406351089  5.0
# 2  126.86828451767764   37.54864378487966  5.0
# 3    126.844478845194    37.5088957497724  5.0
# 4    126.832899709504     37.538667947389  5.0
# 5    126.833548267272    37.5375507231889  5.0
# 6    126.903724199835     37.475607220937  5.0
# 7                 NaN                 NaN  NaN
# 8                 NaN                 NaN  NaN
# 9  126.82726603340956  37.569087404945236  5.0

# %% [markdown]
# ### 2차 데이터 전처리

# %%
# 내 지역구가 아닌 지역구
not_my_area = ['강남구', '도봉구', '중구', '중랑구', '광진구', '마포구',
               '금천구', '서초구', '성동구', '동대문구', '송파구', '동작구', 
               '강서구', '노원구', '강동구', '영등포구', '강북구', '관악구', '은평구', '구로구']

# 내 지역구가 아닌 행의 인덱스를 찾음
rows_to_drop = res_info_df[res_info_df['address_name'].str.contains('|'.join(not_my_area), na=False)].index

# 해당 행을 삭제
res_info_df = res_info_df.drop(rows_to_drop)

# reset_index() 함수를 호출하여 인덱스를 다시 정렬
res_info_df = res_info_df.reset_index(drop=True)

# %%
res_info_df.isna().sum()
# Out:
# address_name           850
# category_group_code    850
# category_group_name    850
# category_name          850
# distance               850
# id                     850
# phone                  850
# place_name             850
# place_url              850
# road_address_name      850
# x                      850
# y                      850
# 평점                     850
# dtype: int64

# %%
# 서울 아닌 행, NaN값 삭제
rows_to_drop2 = res_info_df[~res_info_df['address_name'].str.startswith('서울', na=False)].index
res_info_df = res_info_df.drop(rows_to_drop2)
res_info_df = res_info_df.reset_index(drop=True)

# %%
res_info_df.isna().sum()
# Out:
# address_name           0
# category_group_code    0
# category_group_name    0
# category_name          0
# distance               0
# id                     0
# phone                  0
# place_name             0
# place_url              0
# road_address_name      0
# x                      0
# y                      0
# 평점                     0
# dtype: int64

# %%
# 카테고리 전처리

# %% [markdown]
# ### 최종 데이터프레임

# %%
res_info_df
# Out:
#            address_name category_group_code category_group_name  \
# 0     서울 양천구 신월동 110-29                 FD6                 음식점
# 1       서울 양천구 목동 601-2                 FD6                 음식점
# 2       서울 양천구 신정동 1294                 FD6                 음식점
# 3       서울 양천구 신월동 62-3                 FD6                 음식점
# 4       서울 양천구 신월동 85-6                 FD6                 음식점
# ...                 ...                 ...                 ...
# 3964  서울 종로구 명륜3가 1-112                 FD6                 음식점
# 3965  서울 종로구 창신동 464-10                 FD6                 음식점
# 3966     서울 종로구 청진동 146                 FD6                 음식점
# 3967  서울 종로구 종로6가 238-2                 FD6                 음식점
# 3968    서울 종로구 체부동 39-2                 FD6                 음식점
#
#               category_name distance         id          phone place_name  \
# 0        음식점 > 술집 > 호프,요리주점            16847780   02-2695-6643      돌솥바베큐
# 1                  음식점 > 한식            16052371                       화이팅
# 2                  음식점 > 분식            20540817   02-2697-8998      선가네분식
# 3        음식점 > 술집 > 호프,요리주점           365036181                     칼포니호프
# 4        음식점 > 술집 > 호프,요리주점            16933981   02-2601-1360       호프광장
# ...                     ...      ...        ...            ...        ...
# 3964               음식점 > 분식            20946662    02-743-9688       김밥친구
# 3965  음식점 > 한식 > 육류,고기 > 오리            11593474    02-743-5186        시골집
# 3966       음식점 > 술집 > 일본식주점            89316784   02-2075-5800        카오리
# 3967         음식점 > 한식 > 감자탕             8313401    02-747-8741    방아다리감자국
# 3968         음식점 > 술집 > 와인바            27301443  070-8878-1412      서촌블루스
#
#                                  place_url    road_address_name  \
# 0      http://place.map.kakao.com/16847780   서울 양천구 곰달래로5길 22-1
# 1      http://place.map.kakao.com/16052371  서울 양천구 목동중앙북로 33-20
# 2      http://place.map.kakao.com/20540817      서울 양천구 신정로14길 1
# 3     http://place.map.kakao.com/365036181       서울 양천구 월정로 229
# 4      http://place.map.kakao.com/16933981       서울 양천구 월정로 215
# ...                                    ...                  ...
# 3964   http://place.map.kakao.com/20946662        서울 종로구 명륜길 29
# 3965   http://place.map.kakao.com/11593474     서울 종로구 종로48길 8-2
# 3966   http://place.map.kakao.com/89316784         서울 종로구 종로 19
# 3967    http://place.map.kakao.com/8313401      서울 종로구 종로39길 50
# 3968   http://place.map.kakao.com/27301443     서울 종로구 자하문로 17-1
#
#                        x                  y    평점
# 0       126.833882712082   37.5316406351089  5.00
# 1     126.86828451767764  37.54864378487966  5.00
# 2       126.844478845194   37.5088957497724  5.00
# 3       126.832899709504    37.538667947389  5.00
# 4       126.833548267272   37.5375507231889  5.00
# ...                  ...                ...   ...
# 3964    126.995226500559   37.5885237796056  4.48
# 3965    127.011346923975   37.5714476946019  4.48
# 3966    126.979918914327   37.5708428652181  4.48
# 3967    127.004577790324   37.5727672079731  4.48
# 3968  126.97189185234338  37.57763202430913  4.48
#
# [3969 rows x 13 columns]

# %%
res_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3969 entries, 0 to 3968
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   address_name         3969 non-null   object
#  1   category_group_code  3969 non-null   object
#  2   category_group_name  3969 non-null   object
#  3   category_name        3969 non-null   object
#  4   distance             3969 non-null   object
#  5   id                   3969 non-null   object
#  6   phone                3969 non-null   object
#  7   place_name           3969 non-null   object
#  8   place_url            3969 non-null   object
#  9   road_address_name    3969 non-null   object
#  10  x                    3969 non-null   object
#  11  y                    3969 non-null   object
#  12  평점                   3969 non-null   float64
# dtypes: float64(1), object(12)
# memory usage: 403.2+ KB

# %% [markdown]
# ### 시각화

# %%
# 라이브러리 로드
import os
import json
import csv
import requests
# !pip install folium
import folium
# !pip install -U googlemaps
import googlemaps
import pandas as pd
import xlrd
import openpyxl
import seaborn as sns
import numpy as np
import platform

# %matplotlib notebook
import matplotlib.pyplot as plt
import warnings
from matplotlib import font_manager, rc

# 주피터 에러 메시지 제거
warnings.filterwarnings(action='ignore')

# Plot 한글 지원
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
elif platform.system() == 'Linux':
    path = "/usr/share/fonts/NanumGothic.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    plt.rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# Google map api key setting 
gmaps_key = "AIzaSyAQNwnr-6CwrTIm13flIWRH1saXt89_Fo0"
gmaps = googlemaps.Client(key=gmaps_key)
# Out:
# Requirement already satisfied: folium in c:\users\ksh\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\ksh\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\ksh\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: numpy in c:\users\ksh\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.6.0 in c:\users\ksh\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ksh\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ksh\anaconda3\lib\site-packages (from requests->folium) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ksh\anaconda3\lib\site-packages (from requests->folium) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ksh\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ksh\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: googlemaps in c:\users\ksh\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\ksh\anaconda3\lib\site-packages (from googlemaps) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ksh\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ksh\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ksh\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ksh\anaconda3\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)

# %%
# 특정 지역구만 시각화
# '종로구','양천구','용산구','서대문구','성북구' 중 선택

area = '성북구'

map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

filtered_df = res_info_df.dropna(subset=['road_address_name', 'place_name', 'category_name', '평점', 'place_url'])

for n in filtered_df[filtered_df['address_name'].str.contains(area)].index:
    tooltip = (
        '<b>- 지역</b>: ' + filtered_df['road_address_name'][n] + '<br>' +
        '<b>- 상호명</b>: ' + filtered_df['place_name'][n] + '<br>' + 
        '<b>- 음식 종류</b>: ' + filtered_df['category_name'][n] + '<br>' + 
        '<b>- 네이버 평점</b>: ' + str(filtered_df['평점'][n]) + '<br>' +
        '<b>- URL</b>: ' + filtered_df['place_url'][n]
    )
    
    folium.Marker(
        [filtered_df['y'][n], filtered_df['x'][n]],
        radius=10, 
        color='#3186cc',
        fill_color='#3186cc', 
        fill=True,
        tooltip=tooltip
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec5691e4c7deda6b6c972c0e706f22e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec5691e4c7deda6b6c972c0e706f22e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec5691e4c7deda6b6c972c0e706f22e1 = L.map(
#                 &quot;map_ec5691e4c7deda6b6c972c0e706f22e1&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e73bc1960ba4ff6d8deb51f3667365fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec5691e4c7deda6b6c972c0e706f22e1);
#
#
#             var marker_4ec3cbcb8c2f5c5bdc066d139ca07abe = L.marker(
#                 [37.5836232465969, 127.021350272962],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_ec5691e4c7deda6b6c972c0e706f22e1);
#
#
#             marker_4ec3cbcb8c2f5c5bdc066d139ca07abe.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울 성북구 고려대로6길 48&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 언더워터 커피 로스터스&lt;br&gt;&lt;b&gt;- 음식 종류&lt;/b&gt;: 음식점 &gt; 카페 &gt; 커피전문점&lt;br&gt;&lt;b&gt;- 네이버 평점&lt;/b&gt;: 5.0&lt;br&gt;&lt;b&gt;- URL&lt;/b&gt;: http://place.map.kakao.com/331906186
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_54c7513e14f111d2f42a308030d6f94c = L.marker(
#                 [37.5892607324926, 127.021496810588],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_ec5691e4c7deda6b6c972c0e706f22e1);
#
#
#             marker_54c7513e14f111d2f42a308030d6f94c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울 성북구 보문로30가길 31&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 니르코브&lt;br&gt;&lt;b&gt;- 음식 종류&lt;/b&gt;: 음식점 &gt; 카페 &gt; 테마카페 &gt; 디저트카페&lt;br&gt;&lt;b&gt;- 네이버 평점&lt;/b&gt;: 4.64&lt;br&gt;&lt;b&gt;- URL&lt;/b&gt;: http://place.map.kakao.com/576623246
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8fc0f02beca78fbb826949213088e500 = L.marker(
#                 [37.58350529736336, 127.02936252268027],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_ec5691e4c7deda6b6c972c0e706f22e1);
#
#
#             marker_8fc0f02beca78fbb826949213088e500.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울 성북구 고려대로24길 60&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 오거리술집&lt;br&gt;&lt;b&gt;- 음식 종류&lt;/b&gt;: 음식점 &gt; 술집 &gt; 실내포장마차&lt;br&gt;&lt;b&gt;- 네이버 평점&lt;/b&gt;: 4.5&lt;br&gt;&lt;b&gt;- URL&lt;/b&gt;: http://place.map.kakao.com/1904554432
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5a139eb3939b697016a9735b4b142be1 = L.marker(
#                 [37.59287592554278, 127.01909850646327],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_ec5691e4c7deda6b6c972c0e706f22e1);
#
#
#             marker_5a139eb3939b697016a9735b4b142be1.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울 성북구 동소문로20나길 47&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 떡군이네떡볶이 성북점&lt;br&gt;&lt;b&gt;- 음식 종류&lt;/b&gt;: 음식점 &gt; 분식 &gt; 떡볶이&lt;br&gt;&lt;b&gt;- 네이버 평점&lt;/b&gt;: 4.55&lt;br&gt;&lt;b&gt;- URL&lt;/b&gt;: http://place.map.kakao.com/1447174644
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_642f98096f5156c0b72860f5478a6e53 = L.marker(
#                 [37.5906561839804, 127.01712439872168],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;radius&quot;: 10}
#             ).addTo(map_ec5691e4c7deda6b6c972c0e706f22e1);
#
#
#             marker_642f98096f5156c0b72860f5478a6e53.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;- 지역&lt;/b&gt;: 서울 성북구 보문로34길 31&lt;br&gt;&lt;b&gt;- 상호명&lt;/b&gt;: 최네집부대찌개 성북점&lt;br&gt;&lt;b&gt;- 음식 종류&lt;/b&gt;: 음식점 &gt; 한식 &gt; 찌개,전골&lt;br&gt;&lt;b&gt;- 네이버 평점&lt;/b&gt;: 5.0&lt;br&gt;&lt;b&gt;- URL&lt;/b&gt;: http://place.map.kakao.com/1625544233
#                  &lt;/div&gt;`,

# %%
num_markers = len(filtered_df[filtered_df['address_name'].str.contains(area)])
print("표시된 마커 개수:", num_markers)
# Out:
# 표시된 마커 개수: 763
